# %%
import pandas as pd

# %%
import bamboolib as bam

# %%
df = pd.read_csv(r'C:\Users\Admin\Documents\Datium\DatiumSample.rpt', sep ='\t')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (27,91) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Check missing value and drop features with more than 50% missing value

# %%
missing = df.isna().sum().div(df.shape[0]).mul(100).to_frame().sort_values(by=0, ascending = False)

# %%
cols_missing = missing[missing[0]>50]
print("There are {} features with NaNs above 50%.".format(len(cols_missing)))
# Out:
# There are 36 features with NaNs above 50%.

# %%
# get the list of features to drop due to significant number of missing value
cols_to_drop = list(cols_missing.index)

# %%
df = df.drop(columns=cols_to_drop)

# %% [markdown]
# # Calculate the median value of feature for each car model

# %%
modelfeature = df.groupby(['Model']).agg(FuelUrbanModel=('FuelUrban', 'median'), FuelExtraurbanModel=('FuelExtraurban', 'median'),
                                PayLoadModel=('PayLoad', 'median'), TareMassModel=('TareMass', 'median'),
                                KerbWeightModel=('KerbWeight', 'median'), RonRatingModel=('RonRating', 'median'),
                                GrossVehicleMassModel=('GrossVehicleMass', 'median'),  GreenhouseRatingModel=('GreenhouseRating', 'median'),
                                AirpollutionRatingModel=('AirpollutionRating', 'median'), OverallGreenStarRatingModel=('OverallGreenStarRating', 'median'),
                                FuelCombinedModel=('FuelCombined', 'median'), CO2CombinedModel=('CO2Combined', 'median'),
                                AncapRatingModel=('AncapRating', 'median')).reset_index()

# %% [markdown]
# # Join with original df, replace missing value with median value of the car model

# %%
df = pd.merge(df, modelfeature.drop(columns=[]), how='left', on=['Model'])
df['FuelUrbanFinal'] = df['FuelUrban'].combine_first(df['FuelUrbanModel'])
df['FuelExtraurbanFinal'] = df['FuelExtraurban'].combine_first(df['FuelExtraurbanModel'])
df['PayLoadFinal'] = df['PayLoad'].combine_first(df['PayLoadModel'])
df['TareMassFinal'] = df['TareMass'].combine_first(df['TareMassModel'])
df['KerbWeightFinal'] = df['KerbWeight'].combine_first(df['KerbWeightModel'])
df['GrossVehicleMassFinal'] = df['GrossVehicleMass'].combine_first(df['GrossVehicleMassModel'])
df['RonRatingFinal'] = df['RonRating'].combine_first(df['RonRatingModel'])
df['GreenhouseRatingFinal'] = df['GreenhouseRating'].combine_first(df['GreenhouseRatingModel'])
df['AirpollutionRatingFinal'] = df['AirpollutionRating'].combine_first(df['AirpollutionRatingModel'])
df['OverallGreenStarRatingFinal'] = df['OverallGreenStarRating'].combine_first(df['OverallGreenStarRatingModel'])
df['FuelCombinedFinal'] = df['FuelCombined'].combine_first(df['FuelCombinedModel'])
df['CO2CombinedFinal'] = df['CO2Combined'].combine_first(df['CO2CombinedModel'])
df['AncapRatingFinal'] = df['AncapRating'].combine_first(df['AncapRatingModel'])

# %%
col_drop = ['VIN','ModelCode','EngineNum','Sold_Date','Compliance_Date', 'AvgWholesale', 'AvgRetail', 'GoodWholesale', 
            'GoodRetail', 'TradeMin', 'TradeMax', 'PrivateMax','FuelUrban', 'FuelExtraurban', 'PayLoad', 'TareMass','KerbWeight',
           'FuelUrbanModel', 'FuelExtraurbanModel', 'PayLoadModel', 'TareMassModel','KerbWeightModel','GrossVehicleMassModel', 
           'GrossVehicleMass', 'Make','Model', 'Description', 'RonRating','RonRatingModel','GreenhouseRating','GreenhouseRatingModel',
           'AirpollutionRating', 'AirpollutionRatingModel', 'OverallGreenStarRating', 'OverallGreenStarRatingModel', 'FuelCombined', 
           'FuelCombinedModel','CO2Combined','CO2CombinedModel','AncapRating','AncapRatingModel']
df = df.drop(columns=col_drop)

# %%
df['Series'] = df['Series'].fillna('No Series')
df['BadgeDescription'] = df['BadgeDescription'].fillna('No BadgeDescription')
df['VFactsPrice'] = df['VFactsPrice'].fillna('No VFactsPrice')

# %%
df = df.loc[df['Sold_Amount'].isna() == False]

# %%
df
# Out:
#       MakeCode FamilyCode  YearGroup  MonthGroup  SequenceNum CurrentRelease  \
# 0         HOLD    COMMODO       2008           0            0              F
# 1         HOLD    COMMODO       1993           7           41              F
# 2         TOYO       RAV4       2012           0            6              F
# 3         HOLD    COMMODO       2007           0           11              F
# 4         TOYO     TARAGO       2007           0            0              F
# ...        ...        ...        ...         ...          ...            ...
# 62186     FORD     RANGER       2012           0           22              F
# 62187     FORD     FALCON       2003           0            1              F
# 62188     FORD     FALCON       2001          10           40              F
# 62189     MITS     LANCER       2011          10           24              F
# 62190     HOLD    CAPTIVA       2012           0            4              F
#
#       ImportFlag LimitedEdition        Series BadgeDescription  ...  \
# 0              L              F            VE            Omega  ...
# 1              L              F            VR        Executive  ...
# 2              L              F        ACA33R               CV  ...
# 3              L              F         VZ@VE        Executive  ...
# 4              L              F        ACR50R              GLi  ...
# ...          ...            ...           ...              ...  ...
# 62186          L              F            PX               XL  ...
# 62187          L              F            BA               XT  ...
# 62188          L              F        AU III           Futura  ...
# 62189          L              F            CJ               ES  ...
# 62190          L              F  CG Series II                7  ...
#
#       TareMassFinal KerbWeightFinal GrossVehicleMassFinal RonRatingFinal  \
# 0            1622.0          1690.0                2051.0           91.0
# 1            1380.0          1380.0                2051.0           91.0
# 2            1510.0          1545.0                2060.0           91.0
# 3            1576.0          1576.0                2051.0           91.0
# 4            1685.0          1725.0                2430.0           91.0
# ...             ...             ...                   ...            ...
# 62186        1861.0          1938.0                3200.0           91.0
# 62187        1628.0          1648.0                2210.0           91.0
# 62188        1514.0          1514.0                2210.0           91.0
# 62189        1279.0          1315.0                1850.0           91.0
# 62190        1810.0          1764.0                2505.0           91.0
#
#       GreenhouseRatingFinal  AirpollutionRatingFinal  \
# 0                       5.0                      5.0
# 1                       5.0                      5.0
# 2                       6.0                      6.5
# 3                       4.5                      5.0
# 4                       5.5                      6.5
# ...                     ...                      ...
# 62186                   5.5                      3.0
# 62187                   5.0                      5.0
# 62188                   5.0                      5.0
# 62189                   7.0                      6.5
# 62190                   6.0                      5.0
#
#        OverallGreenStarRatingFinal  FuelCombinedFinal CO2CombinedFinal  \
# 0                              3.0               10.9            260.0
# 1                              3.0                9.2            260.0
# 2                              3.5                9.1            213.0
# 3                              3.0               11.2            264.0
# 4                              3.5                9.5            222.0
# ...                            ...                ...              ...
# 62186                          2.5                8.9            235.0
# 62187                          3.0               11.5            255.0
# 62188                          3.0                8.5            255.0
# 62189                          3.5                7.2            169.0
# 62190                          3.0                8.1            213.0
#
#        AncapRatingFinal
# 0                   4.0
# 1                   5.0
# 2                   4.0
# 3                   4.0
# 4                   5.0
# ...                 ...
# 62186               5.0
# 62187               4.0
# 62188               4.0
# 62189               5.0
# 62190               5.0
#
# [62188 rows x 79 columns]

# %%
df.to_csv('Clean_df.csv', index = False)

# %%
df = pd.read_csv('Clean_df.csv')

# %% [markdown]
# # Model training

# %%
from pycaret.regression import *

# %%
reg1 = setup(data = df, target = 'Sold_Amount', categorical_imputation = 'constant', numeric_imputation = 'median', 
            normalize = True, combine_rare_levels = True, remove_multicollinearity = True, pca = True, 
            log_experiment = True, experiment_name = 'datium',  train_size = 0.75,
            pca_components = 0.95, feature_selection = True, ignore_low_variance = True, remove_outliers = True,
            high_cardinality_features = ['MakeCode','FamilyCode','Series','BadgeDescription','EngineDescription',
                                         'FrontTyreSize', 'RearTyreSize', 'FrontRimDesc','RearRimDesc', 'Colour'])
# Out:
# <style  type="text/css" >
# #T_d56385f1_3fa4_11ec_b184_c8e265d1091frow3_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow7_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow17_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow27_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow31_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow34_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow35_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow38_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow40_col1,#T_d56385f1_3fa4_11ec_b184_c8e265d1091frow49_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_d56385f1_3fa4_11ec_b184_c8e265d1091f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow0_col1" class="data row0 col1" >692</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow1_col1" class="data row1 col1" >Sold_Amount</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow2_col1" class="data row2 col1" >(62188, 79)</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow3_col1" class="data row3 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow4_col1" class="data row4 col1" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow5_col1" class="data row5 col1" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow7_col1" class="data row7 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow8_col1" class="data row8 col1" >frequency</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow9_col1" class="data row9 col1" >(44309, 58)</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow10_col1" class="data row10 col1" >(15547, 58)</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d56385f1_3fa4_11ec_b184_c8e265d1091flevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_d56385f1_3fa4_11ec_b184_c8e265d1091frow17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091f th {
#           text-align: left;
#     }#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col6,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow12_col0,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow12_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow12_col2,#T_5492a3 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col1,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col2,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col3,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col4,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col5,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow0_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow1_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow2_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow3_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow4_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow5_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow6_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow8_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow9_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow10_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow11_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow12_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow13_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow14_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow15_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow16_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow17_col7,#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_5492a3ec_3fa3_11ec_bfe3_c8e265d1091frow7_col7{
#             text-align:  left;
#             text-align:  left;

# %%
cat = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow10_col0,#T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow10_col1,#T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow10_col2,#T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow10_col3,#T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow10_col4,#T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow10_col5{
#             background:  yellow;
#         }</style><table id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow0_col0" class="data row0 col0" >1777.4734</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow0_col1" class="data row0 col1" >7508026.5856</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow0_col2" class="data row0 col2" >2740.0778</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow0_col3" class="data row0 col3" >0.9116</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow0_col4" class="data row0 col4" >1.0129</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow0_col5" class="data row0 col5" >0.1431</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow1_col0" class="data row1 col0" >1869.2403</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow1_col1" class="data row1 col1" >8251808.7037</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow1_col2" class="data row1 col2" >2872.5962</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow1_col3" class="data row1 col3" >0.9094</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow1_col4" class="data row1 col4" >1.0947</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow1_col5" class="data row1 col5" >0.1454</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow2_col0" class="data row2 col0" >1847.8884</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow2_col1" class="data row2 col1" >8434514.9979</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow2_col2" class="data row2 col2" >2904.2236</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow2_col3" class="data row2 col3" >0.9069</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow2_col4" class="data row2 col4" >0.9102</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow2_col5" class="data row2 col5" >0.1535</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow3_col0" class="data row3 col0" >1806.3664</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow3_col1" class="data row3 col1" >8032419.1931</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow3_col2" class="data row3 col2" >2834.1523</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow3_col3" class="data row3 col3" >0.9046</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow3_col4" class="data row3 col4" >0.9826</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow3_col5" class="data row3 col5" >0.1415</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow4_col0" class="data row4 col0" >1874.9844</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow4_col1" class="data row4 col1" >8868780.9791</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow4_col2" class="data row4 col2" >2978.0499</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow4_col3" class="data row4 col3" >0.8947</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow4_col4" class="data row4 col4" >1.0418</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow4_col5" class="data row4 col5" >0.1389</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow5_col0" class="data row5 col0" >1891.0124</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow5_col1" class="data row5 col1" >8779164.4219</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow5_col2" class="data row5 col2" >2962.9655</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow5_col3" class="data row5 col3" >0.9036</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow5_col4" class="data row5 col4" >1.0628</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow5_col5" class="data row5 col5" >0.1553</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow6_col0" class="data row6 col0" >1868.1518</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow6_col1" class="data row6 col1" >8109431.9364</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow6_col2" class="data row6 col2" >2847.7064</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow6_col3" class="data row6 col3" >0.9069</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow6_col4" class="data row6 col4" >1.0031</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow6_col5" class="data row6 col5" >0.1518</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow7_col0" class="data row7 col0" >1875.9680</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow7_col1" class="data row7 col1" >8632960.3046</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow7_col2" class="data row7 col2" >2938.1900</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow7_col3" class="data row7 col3" >0.9059</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow7_col4" class="data row7 col4" >1.0268</td>
#                         <td id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091frow7_col5" class="data row7 col5" >0.1478</td>
#             </tr>
#             <tr>
#                         <th id="T_07f4e5c2_3fa5_11ec_84b5_c8e265d1091flevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_07f4e5c2_3fa5_11e

# %%
pred_holdout = predict_model(cat)
# Out:
# <style  type="text/css" >
# </style><table id="T_aece6b17_3fa5_11ec_a691_c8e265d1091f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aece6b17_3fa5_11ec_a691_c8e265d1091flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col1" class="data row0 col1" >2020.0579</td>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col2" class="data row0 col2" >14311919.2808</td>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col3" class="data row0 col3" >3783.1097</td>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col4" class="data row0 col4" >0.8709</td>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col5" class="data row0 col5" >1.0452</td>
#                         <td id="T_aece6b17_3fa5_11ec_a691_c8e265d1091frow0_col6" class="data row0 col6" >0.1665</td>
#             </tr>
#     </tbody></table>

# %%
pred_holdout.head(25)
# Out:
#     Component_1  Component_2  Component_3  Component_4  Component_5  \
# 0     -3.418466    -0.908455     2.143339     0.892868     1.049380
# 1     -1.539319     2.552288     2.229918     0.810014    -1.642902
# 2     -0.119329     2.420010    -1.373034     0.572312    -0.020909
# 3     -3.918201    -0.880879     2.759071     0.547067     1.782932
# 4      2.529789    -4.900937     0.089366    -1.196182     0.534939
# 5     -1.485114     0.736239    -2.513442     0.606258     0.822800
# 6     -2.637352     1.559095     1.683104    -1.805366    -1.296367
# 7      1.664912     1.014272     2.585502     2.263170    -2.612011
# 8     -2.876826    -1.691432    -3.744073     1.688864     0.972177
# 9     -1.006963    -0.938471     0.847584     1.541923    -0.731929
# 10     3.150940    -2.636655     0.100145    -3.643634     0.728662
# 11    -7.351092    -2.156495     1.207223     0.903466     1.200093
# 12    -2.809807     2.266687     0.419238    -2.589530    -1.341353
# 13     3.102655    -2.226677     0.537781    -3.501956    -0.025510
# 14    -3.727314    -1.584048     0.028695     0.121168     0.745001
# 15    -5.406050    -0.200333     0.663525    -1.327777    -1.719255
# 16     0.837323    -3.471572    -2.446354    -0.826536    -2.210700
time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                                         correlation_with_target_threshold=0.0,
#                                         target_variable='Sold_Amount',
#                                         threshold=0.9)),
#                  ('dfs', 'passthrough'),
#                  ('pca',
#                   Reduce_Dimensions_For_Supervised_Path(method='pca_liner',
#                                                         random_state=5831,
#                                                         target='Sold_Amount',
#                                                         variance_retained_or_number_of_components=None)),
#                  ['trained_model',
#                   <catboost.core.CatBoostRegressor object at 0x000002B12A60C880>]],
#           verbose=False),
#  'C:\\Users\\Admin\\Documents\\Datium\\Experiment\\Run 3\\Cat_Boost.pkl')

# %%
file_loc = (r'C:\Users\Admin\Documents\Datium\Experiment\Run 3\Run3vars.pkl')
save_config(file_loc)

# %%
df
# Out:
#       MakeCode FamilyCode  YearGroup  MonthGroup  SequenceNum CurrentRelease  \
# 0         HOLD    COMMODO       2008           0            0              F
# 1         HOLD    COMMODO       1993           7           41              F
# 2         TOYO       RAV4       2012           0            6              F
# 3         HOLD    COMMODO       2007           0           11              F
# 4         TOYO     TARAGO       2007           0            0              F
# ...        ...        ...        ...         ...          ...            ...
# 62183     FORD     RANGER       2012           0           22              F
# 62184     FORD     FALCON       2003           0            1              F
# 62185     FORD     FALCON       2001          10           40              F
# 62186     MITS     LANCER       2011          10           24              F
# 62187     HOLD    CAPTIVA       2012           0            4              F
#
#       ImportFlag LimitedEdition        Series BadgeDescription  ...  \
# 0              L              F            VE            Omega  ...
# 1              L              F            VR        Executive  ...
# 2              L              F        ACA33R               CV  ...
# 3              L              F         VZ@VE        Executive  ...
# 4              L              F        ACR50R              GLi  ...
# ...          ...            ...           ...              ...  ...
# 62183          L              F            PX               XL  ...
# 62184          L              F            BA               XT  ...
# 62185          L              F        AU III           Futura  ...
# 62186          L              F            CJ               ES  ...
# 62187          L              F  CG Series II                7  ...
#
#       TareMassFinal KerbWeightFinal GrossVehicleMassFinal RonRatingFinal  \
# 0            1622.0          1690.0                2051.0           91.0
# 1            1380.0          1380.0                2051.0           91.0
# 2            1510.0          1545.0                2060.0           91.0
# 3            1576.0          1576.0                2051.0           91.0
# 4            1685.0          1725.0                2430.0           91.0
# ...             ...             ...                   ...            ...
# 62183        1861.0          1938.0                3200.0           91.0
# 62184        1628.0          1648.0                2210.0           91.0
# 62185        1514.0          1514.0                2210.0           91.0
# 62186        1279.0          1315.0                1850.0           91.0
# 62187        1810.0          1764.0                2505.0           91.0
#
#       GreenhouseRatingFinal  AirpollutionRatingFinal  \
# 0                       5.0                      5.0
# 1                       5.0                      5.0
# 2                       6.0                      6.5
# 3                       4.5                      5.0
# 4                       5.5                      6.5
# ...                     ...                      ...
# 62183                   5.5                      3.0
# 62184                   5.0                      5.0
# 62185                   5.0                      5.0
# 62186                   7.0                      6.5
# 62187                   6.0                      5.0
#
#        OverallGreenStarRatingFinal  FuelCombinedFinal CO2CombinedFinal  \
# 0                              3.0               10.9            260.0
# 1                              3.0                9.2            260.0
# 2                              3.5                9.1            213.0
# 3                              3.0               11.2            264.0
# 4                              3.5                9.5            222.0
# ...                            ...                ...              ...
# 62183                          2.5                8.9            235.0
# 62184                          3.0               11.5            255.0
# 62185                          3.0                8.5            255.0
# 62186                          3.5                7.2            169.0
# 62187                          3.0                8.1            213.0
#
#        AncapRatingFinal
# 0                   4.0
# 1                   5.0
# 2                   4.0
# 3                   4.0
# 4                   5.0
# ...                 ...
# 62183               5.0
# 62184               4.0
# 62185               4.0
# 62186               5.0
# 62187               5.0
#
# [62188 rows x 79 columns]
